# %% [markdown]
# # TM10007 Assignment ECG - Group 3
#
# *Authors: Pien van Gastel (5389879), Koen Kwakkenbos (4858956), Hilde van der Pol (4663209), Fenna van der Zijden (4484665)*
#
# This file contains the code accompanying our TM10007 report
#
# > Diagnosis of abnormalities in an 12-lead ECG
#
# This notebook contains the following elements:
#
# Running the sections `Setup`, `PCA plot & data visualization`, `Model training`, and `Statistical analysis` will reproduce the results as presented in our report and its appendices. After the section `Statistical analysis`, the section `Intermediate results` contains 4 hidden cells displaying an alternative approach concerning feature preprocessing (standard scaling in combination with PCA), that was inferior to the methods that were used to obtain the results in the report.
#
# (!) Please note that the SVM in combination with PCA (hidden at end of notebook) keeps running for a very long time, and running was halted by us as there seemed to be no progression.
#
# *The estimated running time of this notebook is 50 minutes (excluding the hidden sections at the end).*

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
# !pip install jinja2

import zipfile
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn

from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA 
from sklearn.feature_selection import SelectKBest, chi2, SequentialFeatureSelector
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV, learning_curve
from sklearn.svm import SVC
from sklearn.model_selection import ShuffleSplit, StratifiedShuffleSplit
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.feature_selection import SelectKBest, chi2, SequentialFeatureSelector
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, Normalizer
from IPython.display import display
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from itertools import combinations
from scipy.stats import ttest_rel, ttest_ind
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve, auc
# Out:
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2) (2.0.1)

# %% [markdown]
# ### Data loading, save features and labels into dataframe

# %%
# Run this to use from colab environment
# !git clone https://github.com/jveenland/tm10007_ml.git

with zipfile.ZipFile('/content/tm10007_ml/ecg/ecg_data.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/tm10007_ml/ecg')

data = pd.read_csv('/content/tm10007_ml/ecg/ecg_data.csv', index_col=0)

print(f'The number of samples: {len(data.index)}')
print(f'The number of columns: {len(data.columns)}')

y = data.label
X = data.drop('label', axis=1)
# Out:
# fatal: destination path 'tm10007_ml' already exists and is not an empty directory.
# The number of samples: 827
# The number of columns: 9001

# %% [markdown]
# ### Constants

# %%
N_SPLITS = 5 # number of splits for outer validation loop
RANDOM_SEED = 42 # get reproducable splits for the different models

# %% [markdown]
# ### Learning Curve function

# %%
def plot_learning_curve(clf, X_train, y_train, plot):
    train_size, train_scores, test_scores = learning_curve(clf, X_train, y_train, scoring='roc_auc')
    
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    plot.plot(train_size, train_mean, color='b', label='training')
    plot.plot(train_size, test_mean, color='orange', label='validation')

    plot.fill_between(train_size, train_mean-train_std, train_mean+train_std, color='b', alpha=0.3)
    plot.fill_between(train_size, test_mean-test_std, test_mean+test_std, color='orange', alpha=0.3)
    
    plot.grid()
    plot.set_ylim([0.5, 1.1])
    plot.set_xlabel('Training examples')
    plot.set_ylabel('ROC-AUC Score')
    plot.legend()

# %% [markdown]
# ## PCA plot & data visualization

# %%
# PCA plot of all data
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)

# we dachten PCA scatterplots van verschillende data toevoegen in subplot 
pca = PCA()
pca.fit(X_scaled)
X_pca = pca.transform(X_scaled)

fig, axs = plt.subplots(1, 3, figsize=(30,10))
seaborn.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, ax=axs[0])
axs[0].set_title('First component vs. second component')
axs[0].grid()
seaborn.scatterplot(x=X_pca[:, 1], y=X_pca[:, 2], hue=y, ax=axs[1])
axs[1].set_title('Second component vs. third component')
axs[1].grid()
seaborn.scatterplot(x=X_pca[:, 2], y=X_pca[:, 3], hue=y, ax=axs[2])
axs[2].set_title('Third component vs. Fourth component')
axs[2].grid()

# %%
plt.bar(x=range(pca.explained_variance_ratio_.shape[0]), height=pca.explained_variance_ratio_)
plt.xlim([0, 75])
# Out:
# (0.0, 75.0)

# %% [markdown]
# ## Model training

# %% [markdown]
# ### K-Nearest Neighbours

# %% [markdown]
# #### Training-Testing using scaling and k-best feature selection

# %%
rs = StratifiedShuffleSplit(n_splits=N_SPLITS, test_size=.3, random_state=RANDOM_SEED)

scores_knn = {'f1': [], 'accuracy': [], 'AUC': []}
fitted_clf_list_knn = []

fig, axs = plt.subplots(N_SPLITS, figsize=(10, 10))

for i, (train_index, test_index) in enumerate(rs.split(X, y)):

    # Data split
    X_train = X.iloc[train_index]
    y_train = y[train_index]
    X_test = X.iloc[test_index]
    y_test = y[test_index]

    # Preprocessing
    scaler = StandardScaler()
    selector = SelectKBest()
    
    # Classifier
    knn = KNeighborsClassifier()

    # Pipeline
    pipe = Pipeline(steps=[('scaler', scaler), ('select', selector), ("knn", knn)])

    # Random grid:
    pca_components = [None] + list(np.arange(1, 101, 20))
    k_range = list(range(1, 31))
    weights = ['uniform', 'distance']
    k_select = np.arange(2, 150)

    random_grid = {'knn__n_neighbors': k_range,
    'knn__weights': weights,
    'select__k': k_select}

    # Hoeveel iteraties willen we?
    search = RandomizedSearchCV(pipe, random_grid, cv=5, scoring = 'f1', n_iter=20, random_state=RANDOM_SEED)
    search.fit(X_train, y_train)
    best_clf = search.best_estimator_
    fitted_clf_list_knn.append(search)
    
    # evaluation
    y_pred = best_clf.predict(X_test)
    y_score = best_clf.predict_proba(X_test)
    scores_knn['f1'] += [f1_score(y_test, y_pred)]
    scores_knn['accuracy'] += [accuracy_score(y_test, y_pred)]
    scores_knn['AUC'] += [roc_auc_score(y_test, y_score[:,1])]
    
    # Predictions
    scores_knn[f'probs_split_{i+1}'] = y_score
    scores_knn[f'labels_split_{i+1}'] = list(y_test)

    plot_learning_curve(best_clf, X_train, y_train, axs[i]) # eventueel testen met groot aantal neighbors
    fig.suptitle(f'Learning curve for {str(type(best_clf[-1])).split(".")[-1][:-2]}')
plt.show()

# %% [markdown]
# #### Results - Overall metrics

# %%
print('F1-scores:')
print(f"{scores_knn['f1']}, mean: {np.mean(scores_knn['f1'])}, std: {np.std(scores_knn['f1'])}")
print('Accuracy:')
print(f"{scores_knn['accuracy']}, mean: {np.mean(scores_knn['accuracy'])}, std: {np.std(scores_knn['accuracy'])}")
print('AUC:')
print(f"{scores_knn['AUC']}, mean: {np.mean(scores_knn['AUC'])}, std: {np.std(scores_knn['AUC'])}")
# Out:
# F1-scores:
# [0.3116883116883117, 0.3283582089552239, 0.2711864406779661, 0.33333333333333326, 0.2816901408450704], mean: 0.305251287099981, std: 0.02481736415668658
# Accuracy:
# [0.7871485943775101, 0.8192771084337349, 0.8273092369477911, 0.8072289156626506, 0.7951807228915663], mean: 0.8072289156626506, std: 0.014810513184406224
# AUC:
# [0.6439024390243903, 0.6635809312638582, 0.65, 0.6589800443458981, 0.6277161862527717], mean: 0.6488359201773837, std: 0.012586151804688072

# %% [markdown]
# #### Results - Hyperparameter search

# %%
import pandas as pd
for i, clf in enumerate(fitted_clf_list_knn): 
    print(f'Results for split {i+1}:')
    param_df = pd.DataFrame(clf.cv_results_)

    # columns to drop from dataframe:
    param_df = param_df.drop(['std_fit_time', 'mean_score_time', 'std_score_time'], axis=1)
    cols = [c for c in param_df.columns if c.lower()[:5] != 'split']
    
    param_df = param_df[cols].sort_values(by='rank_test_score')
    display(param_df.head(5))
# Out:
# Results for split 1:
#     mean_fit_time param_select__k param_knn__weights param_knn__n_neighbors  \
# 6        0.489963              24           distance                      2
# 1        0.658718             122           distance                      3
# 17       0.260694               2            uniform                      5
# 10       0.303616              59           distance                      6
# 11       0.308218              31           distance                      3
#
#                                                params  mean_test_score  \
# 6   {'select__k': 24, 'knn__weights': 'distance', ...         0.398250
# 1   {'select__k': 122, 'knn__weights': 'distance',...         0.368535
# 17  {'select__k': 2, 'knn__weights': 'uniform', 'k...         0.336844
# 10  {'select__k': 59, 'knn__weights': 'distance', ...         0.325245
# 11  {'select__k': 31, 'knn__weights': 'distance', ...         0.310378
#
#     std_test_score  rank_test_score
# 6         0.058986                1
# 1         0.113827                2
# 17        0.069839                3
# 10        0.077437                4
# 11        0.100797                5
# Results for split 2:
#     mean_fit_time param_select__k param_knn__weights param_knn__n_neighbors  \
# 6        0.315439              24           distance                      2
# 11       0.319574              31           distance                      3
# 17       0.281476               2            uniform                      5
# 1        0.317150             122           distance                      3
# 10       0.311794              59           distance                      6
#
#                                                params  mean_test_score  \
# 6   {'select__k': 24, 'knn__weights': 'distance', ...         0.342832
# 11  {'select__k': 31, 'knn__weights': 'distance', ...         0.265627
# 17  {'select__k': 2, 'knn__weights': 'uniform', 'k...         0.264360
# 1   {'select__k': 122, 'knn__weights': 'distance',...         0.262788
# 10  {'select__k': 59, 'knn__weights': 'distance', ...         0.228248
#
#     std_test_score  rank_test_score
# 6         0.102430                1
# 11        0.101255                2
# 17        0.110648                3
# 1         0.115191                4
# 10        0.069688                5
# Results for split 3:
#     mean_fit_time param_select__k param_knn__weights param_knn__n_neighbors  \
# 11       0.315929              31           distance                      3
# 1        0.317454             122           distance                      3
# 10       0.317721              59           distance                      6
# 6        0.317628              24           distance                      2
# 17       0.273695               2            uniform                      5
#
#                                                params  mean_test_score  \
# 11  {'select__k': 31, 'knn__weights': 'distance', ...         0.374842
# 1   {'select__k': 122, 'knn__weights': 'distance',...         0.314156
# 10  {'select__k': 59, 'knn__weights': 'distance', ...         0.280127
# 6   {'select__k': 24, 'knn__weights': 'distance', ...         0.268780
# 17  {'select__k': 2, 'knn__weights': 'uniform', 'k...         0.189524
#
#     std_test_score  rank_test_score
# 11        0.075753                1
# 1         0.060254                2
# 10        0.085020                3
# 6         0.103592                4
# 17        0.107176                5
# Results for split 4:
#     mean_fit_time param_select__k param_knn__weights param_knn__n_neighbors  \
# 6        0.316580              24           distance                      2
# 11       0.318551              31           distance                      3
# 1        0.317513             122           distance                      3
# 10       0.312942              59           distance                      6
# 17       0.275458               2            uniform                      5
#
#                                                params  mean_test_score  \
# 6   {'select__k': 24, 'knn__weights': 'distance', ...         0.527912
# 11  {'select__k': 31, 'knn__weights': 'distance', ...         0.451037
# 1   {'select__k': 122, 'knn__weights': 'distance',...         0.379505
# 10  {'select__k': 59, 'knn__weights': 'distance', ...         0.363597
# 17  {'select__k': 2, 'knn__weights': 'uniform', 'k...         0.321407
#
#     std_test_score  rank_test_score
# 6         0.071456                1
# 11        0.079359                2
# 1         0.120906                3
# 10        0.084596                4
# 17        0.071497                5
# Results for split 5:
#     mean_fit_time param_select__k param_knn__weights param_knn__n_neighbors  \
# 6        0.312274              24           distance                      2
# 17       0.274041               2            uniform                      5
# 11       0.317607              31           distance                      3
# 1        0.311504             122           distance                      3
# 10       0.312561              59           distance                      6
#
#                                                params  mean_test_score  \
# 6   {'select__k': 24, 'knn__weights': 'distance', ...         0.403081
# 17  {'select__k': 2, 'knn__weights': 'uniform', 'k...         0.400906
# 11  {'select__k': 31, 'knn__weights': 'distance', ...         0.386905
# 1   {'select__k': 122, 'knn__weights': 'distance',...         0.307207
# 10  {'select__k': 59, 'knn__weights': 'distance', ...         0.276480
#
#     std_test_score  rank_test_score
# 6         0.084473                1
# 17        0.106123                2
# 11        0.159652                3
# 1         0.147553                4
# 10        0.087488                5

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# #### Training-Testing using k-best feature selection

# %%
rs = StratifiedShuffleSplit(n_splits=N_SPLITS, test_size=.3, random_state=RANDOM_SEED)

scores_nb = {'f1': [], 'accuracy': [], 'AUC': []}
fitted_clf_list_nb = []

fig, axs = plt.subplots(N_SPLITS, figsize=(10, 10))

for i, (train_index, test_index) in enumerate(rs.split(X, y)):

    # Data split
    X_train = X.iloc[train_index]
    y_train = y[train_index]
    X_test = X.iloc[test_index]
    y_test = y[test_index]

    # Preprocessing
    scaler = StandardScaler()
    selector = SelectKBest()
    
    # Classifier
    naive_bayes = GaussianNB()

    # Pipeline
    pipe = Pipeline(steps=[('select', selector), ("nbayes", naive_bayes)])

    # Random grid:
    pca_components = [None] + list(np.arange(1, 101, 20))
    var_smoothing = np.logspace(0,-9, num=100)
    k_select = np.arange(2, 150)

    random_grid = {'nbayes__var_smoothing': var_smoothing,
    'select__k': k_select}

    search = RandomizedSearchCV(pipe, random_grid, cv=5, scoring = 'f1', n_iter= 20, random_state=RANDOM_SEED)
    search.fit(X_train, y_train)
    best_clf = search.best_estimator_
    fitted_clf_list_nb.append(search)

    # Evaluation
    y_pred = best_clf.predict(X_test)
    y_score = best_clf.predict_proba(X_test)
    scores_nb['f1'] += [f1_score(y_test, y_pred)]
    scores_nb['accuracy'] += [accuracy_score(y_test, y_pred)]
    scores_nb['AUC'] += [roc_auc_score(y_test, y_score[:,1])]

    # Predictions
    scores_nb[f'probs_split_{i+1}'] = y_score
    scores_nb[f'labels_split_{i+1}'] = list(y_test)
    
    plot_learning_curve(best_clf, X_train, y_train, axs[i])
    fig.suptitle(f'Learning curve for {str(type(best_clf[-1])).split(".")[-1][:-2]}')
plt.show()

# %% [markdown]
# #### Results - Overall metrics

# %%
print('F1-scores:')
print(f"{scores_nb['f1']}, mean: {np.mean(scores_nb['f1'])}, std: {np.std(scores_nb['f1'])}")
print('Accuracy:')
print(f"{scores_nb['accuracy']}, mean: {np.mean(scores_nb['accuracy'])}, std: {np.std(scores_nb['accuracy'])}")
print('AUC:')
print(f"{scores_nb['AUC']}, mean: {np.mean(scores_nb['AUC'])}, std: {np.std(scores_nb['AUC'])}")
# Out:
# F1-scores:
# [0.30769230769230765, 0.4444444444444444, 0.3283582089552239, 0.44444444444444453, 0.3733333333333333], mean: 0.3796545477739508, std: 0.05700052200975785
# Accuracy:
# [0.7831325301204819, 0.8393574297188755, 0.8192771084337349, 0.8192771084337349, 0.8112449799196787], mean: 0.8144578313253013, std: 0.018210094857437173
# AUC:
# [0.7241685144124169, 0.765410199556541, 0.7661862527716187, 0.7532150776053215, 0.7405764966740576], mean: 0.749911308203991, std: 0.015911219215318184

# %% [markdown]
# #### Results - Hyperparameter search

# %%
import pandas as pd
for i, clf in enumerate(fitted_clf_list_nb): 
    print(f'Results for split {i+1}:')
    param_df = pd.DataFrame(clf.cv_results_)

    # columns to drop from dataframe:
    param_df = param_df.drop(['std_fit_time', 'mean_score_time', 'std_score_time'], axis=1)
    cols = [c for c in param_df.columns if c.lower()[:5] != 'split']
    
    param_df = param_df[cols].sort_values(by='rank_test_score')
    display(param_df.head(5))
# Out:
# Results for split 1:
#     mean_fit_time param_select__k param_nbayes__var_smoothing  \
# 17       0.216201              36                    0.000008
# 6        0.218032              38                         0.0
# 4        0.211002              13                    0.000658
# 16       0.214205              13                         0.0
# 8        0.215972              51                    0.000152
#
#                                                params  mean_test_score  \
# 17  {'select__k': 36, 'nbayes__var_smoothing': 8.1...         0.512788
# 6   {'select__k': 38, 'nbayes__var_smoothing': 1.2...         0.501689
# 4   {'select__k': 13, 'nbayes__var_smoothing': 0.0...         0.497159
# 16  {'select__k': 13, 'nbayes__var_smoothing': 1.5...         0.492858
# 8   {'select__k': 51, 'nbayes__var_smoothing': 0.0...         0.490568
#
#     std_test_score  rank_test_score
# 17        0.100739                1
# 6         0.097685                2
# 4         0.115488                3
# 16        0.109332                4
# 8         0.086573                5
# Results for split 2:
#     mean_fit_time param_select__k param_nbayes__var_smoothing  \
# 13       0.210602              69                         0.0
# 0        0.209201              20                    0.000035
# 2        0.212280              64                    0.000534
# 10       0.210121              60                         0.0
# 12       0.213141             104                    0.000433
#
#                                                params  mean_test_score  \
# 13  {'select__k': 69, 'nbayes__var_smoothing': 1.5...         0.426842
# 0   {'select__k': 20, 'nbayes__var_smoothing': 3.5...         0.423181
# 2   {'select__k': 64, 'nbayes__var_smoothing': 0.0...         0.422078
# 10  {'select__k': 60, 'nbayes__var_smoothing': 5.3...         0.420691
# 12  {'select__k': 104, 'nbayes__var_smoothing': 0....         0.420173
#
#     std_test_score  rank_test_score
# 13        0.079225                1
# 0         0.076878                2
# 2         0.076068                3
# 10        0.060643                4
# 12        0.068959                5
# Results for split 3:
#     mean_fit_time param_select__k param_nbayes__var_smoothing  \
# 13       0.207320              69                         0.0
# 2        0.212726              64                    0.000534
# 12       0.209597             104                    0.000433
# 7        0.212787             112                    0.000351
# 8        0.209566              51                    0.000152
#
#                                                params  mean_test_score  \
# 13  {'select__k': 69, 'nbayes__var_smoothing': 1.5...         0.459984
# 2   {'select__k': 64, 'nbayes__var_smoothing': 0.0...         0.459550
# 12  {'select__k': 104, 'nbayes__var_smoothing': 0....         0.456273
# 7   {'select__k': 112, 'nbayes__var_smoothing': 0....         0.453428
# 8   {'select__k': 51, 'nbayes__var_smoothing': 0.0...         0.450525
#
#     std_test_score  rank_test_score
# 13        0.113166                1
# 2         0.108367                2
# 12        0.100909                3
# 7         0.098669                4
# 8         0.110976                5
# Results for split 4:
#     mean_fit_time param_select__k param_nbayes__var_smoothing  \
# 0        0.212916              20                    0.000035
# 16       0.208182              13                         0.0
# 4        0.211939              13                    0.000658
# 15       0.214658             117                         0.0
# 10       0.213560              60                         0.0
#
#                                                params  mean_test_score  \
# 0   {'select__k': 20, 'nbayes__var_smoothing': 3.5...         0.479324
# 16  {'select__k': 13, 'nbayes__var_smoothing': 1.5...         0.470520
# 4   {'select__k': 13, 'nbayes__var_smoothing': 0.0...         0.462111
# 15  {'select__k': 117, 'nbayes__var_smoothing': 1....         0.449929
# 10  {'select__k': 60, 'nbayes__var_smoothing': 5.3...         0.446805
#
#     std_test_score  rank_test_score
# 0         0.072184                1
# 16        0.062894                2
# 4         0.063007                3
# 15        0.037360                4
# 10        0.047129                5
# Results for split 5:
#     mean_fit_time param_select__k param_nbayes__var_smoothing  \
# 0        0.211908              20                    0.000035
# 4        0.217414              13                    0.000658
# 16       0.214675              13                         0.0
# 12       0.214462             104                    0.000433
# 15       0.219535             117                         0.0
#
#                                                params  mean_test_score  \
# 0   {'select__k': 20, 'nbayes__var_smoothing': 3.5...         0.479458
# 4   {'select__k': 13, 'nbayes__var_smoothing': 0.0...         0.463929
# 16  {'select__k': 13, 'nbayes__var_smoothing': 1.5...         0.463929
# 12  {'select__k': 104, 'nbayes__var_smoothing': 0....         0.459174
# 15  {'select__k': 117, 'nbayes__var_smoothing': 1....         0.457776
#
#     std_test_score  rank_test_score
# 0         0.140189                1
# 4         0.152114                2
# 16        0.152114                2
# 12        0.148794                4
# 15        0.149343                5

# %% [markdown]
# ### SVM

# %% [markdown]
# #### Training-Testing using k-best feature selection

# %%
# Aantal splits
N_SPLITS = 5

rs = StratifiedShuffleSplit(n_splits=N_SPLITS, test_size=.3, random_state=RANDOM_SEED)

scores_svm = {'f1': [], 'accuracy': [], 'AUC': []}
fitted_clf_list_svm = []

fig, axs = plt.subplots(N_SPLITS, figsize=(10, 10))

for i, (train_index, test_index) in enumerate(rs.split(X, y)):

    # Data split
    X_train = X.iloc[train_index]
    y_train = y[train_index]
    X_test = X.iloc[test_index]
    y_test = y[test_index]

    # Preprocessing
    scaler = StandardScaler()
    selector = SelectKBest()

    # classifier 
    classifier = svm.SVC(probability=True)
    
    # Pipeline
    pipe = Pipeline(steps=[('scaler', scaler), ('select', selector), ('svm', classifier)])

    # GridSearch

    # Random grid:
    random_grid = {
        #'pca__n_components': [None, 10,50,100],
            'svm__C': list(np.arange(0.01,100, 5)),
            'svm__gamma': list(np.arange(0.001, 1, 0.05)), 
            'svm__kernel': ['rbf', 'poly', 'linear'],
            'select__k': np.arange(2, 150)}

    search = RandomizedSearchCV(pipe, random_grid, cv=5, scoring = 'f1', n_iter= 20, random_state=RANDOM_SEED)
    search.fit(X_train, y_train)
    best_clf = search.best_estimator_
    fitted_clf_list_svm.append(search)

    # evaluation
    y_pred = best_clf.predict(X_test)
    y_score = best_clf.predict_proba(X_test)
    scores_svm['f1'] += [f1_score(y_test, y_pred)]
    scores_svm['accuracy'] += [accuracy_score(y_test, y_pred)]
    scores_svm['AUC'] += [roc_auc_score(y_test, y_score[:,1])]

    # Predictions
    scores_svm[f'probs_split_{i+1}'] = y_score
    scores_svm[f'labels_split_{i+1}'] = list(y_test)
    
    plot_learning_curve(best_clf, X_train, y_train, axs[i])
    fig.suptitle(f'Learning curve for {str(type(best_clf[-1])).split(".")[-1][:-2]}')
plt.show()

# %% [markdown]
# #### Results - Overall metrics

# %%
print('F1-scores:')
print(f"{scores_svm['f1']}, mean: {np.mean(scores_svm['f1'])}, std: {np.std(scores_svm['f1'])}")
print('Accuracy:')
print(f"{scores_svm['accuracy']}, mean: {np.mean(scores_svm['accuracy'])}, std: {np.std(scores_svm['accuracy'])}")
print('AUC:')
print(f"{scores_svm['AUC']}, mean: {np.mean(scores_svm['AUC'])}, std: {np.std(scores_svm['AUC'])}")
# Out:
# F1-scores:
# [0.39506172839506176, 0.46511627906976744, 0.4533333333333333, 0.3888888888888889, 0.3333333333333333], mean: 0.4071467126040769, std: 0.04779431870028478
# Accuracy:
# [0.8032128514056225, 0.8152610441767069, 0.8353413654618473, 0.8232931726907631, 0.8232931726907631], mean: 0.8200803212851406, std: 0.010595105187367795
# AUC:
# [0.6985587583148559, 0.7124168514412417, 0.7419068736141906, 0.6883592017738359, 0.6961197339246119], mean: 0.7074722838137472, std: 0.018888255370026835

# %% [markdown]
# #### Results - Hyperparameter search

# %%
import pandas as pd
for i, clf in enumerate(fitted_clf_list_svm): 
    print(f'Results for split {i+1}:')
    param_df = pd.DataFrame(clf.cv_results_)

    # columns to drop from dataframe:
    param_df = param_df.drop(['std_fit_time', 'mean_score_time', 'std_score_time'], axis=1)
    cols = [c for c in param_df.columns if c.lower()[:5] != 'split']
    
    param_df = param_df[cols].sort_values(by='rank_test_score')
    display(param_df.head(5))
# Out:
# Results for split 1:
#     mean_fit_time param_svm__kernel param_svm__gamma param_svm__C  \
# 3        4.456628            linear            0.201        40.01
# 8        0.481354            linear            0.401        20.01
# 18      10.763781            linear            0.551        75.01
# 13       0.320812               rbf            0.051        35.01
# 4        3.842284            linear            0.951        85.01
#
#    param_select__k                                             params  \
# 3               88  {'svm__kernel': 'linear', 'svm__gamma': 0.201,...
# 8              142  {'svm__kernel': 'linear', 'svm__gamma': 0.401,...
# 18              51  {'svm__kernel': 'linear', 'svm__gamma': 0.551,...
# 13              15  {'svm__kernel': 'rbf', 'svm__gamma': 0.0510000...
# 4              101  {'svm__kernel': 'linear', 'svm__gamma': 0.9510...
#
#     mean_test_score  std_test_score  rank_test_score
# 3          0.527211        0.065624                1
# 8          0.512008        0.036476                2
# 18         0.507844        0.052504                3
# 13         0.506053        0.084841                4
# 4          0.486498        0.042046                5
# Results for split 2:
#    mean_fit_time param_svm__kernel param_svm__gamma param_svm__C  \
# 1       1.007473            linear            0.751        35.01
# 8       0.646739            linear            0.401        20.01
# 0       3.313128            linear            0.601        60.01
# 6       0.321901              poly            0.751        70.01
# 2       0.336463              poly            0.851        90.01
#
#   param_select__k                                             params  \
# 1             124  {'svm__kernel': 'linear', 'svm__gamma': 0.751,...
# 8             142  {'svm__kernel': 'linear', 'svm__gamma': 0.401,...
# 0             103  {'svm__kernel': 'linear', 'svm__gamma': 0.6010...
# 6              47  {'svm__kernel': 'poly', 'svm__gamma': 0.751, '...
# 2             111  {'svm__kernel': 'poly', 'svm__gamma': 0.851000...
#
#    mean_test_score  std_test_score  rank_test_score
# 1         0.461328        0.042179                1
# 8         0.454141        0.090406                2
# 0         0.451951        0.072011                3
# 6         0.445415        0.065602                4
# 2         0.441725        0.096498                5
# Results for split 3:
#    mean_fit_time param_svm__kernel param_svm__gamma param_svm__C  \
# 2       0.346620              poly            0.851        90.01
# 1       1.310078            linear            0.751        35.01
# 0       5.262085            linear            0.601        60.01
# 8       0.675873            linear            0.401        20.01
# 4       6.197383            linear            0.951        85.01
#
#   param_select__k                                             params  \
# 2             111  {'svm__kernel': 'poly', 'svm__gamma': 0.851000...
# 1             124  {'svm__kernel': 'linear', 'svm__gamma': 0.751,...
# 0             103  {'svm__kernel': 'linear', 'svm__gamma': 0.6010...
# 8             142  {'svm__kernel': 'linear', 'svm__gamma': 0.401,...
# 4             101  {'svm__kernel': 'linear', 'svm__gamma': 0.9510...
#
#    mean_test_score  std_test_score  rank_test_score
# 2         0.468302        0.115042                1
# 1         0.441807        0.059765                2
# 0         0.432949        0.048785                3
# 8         0.415321        0.019804                4
# 4         0.402417        0.042387                5
# Results for split 4:
#     mean_fit_time param_svm__kernel param_svm__gamma param_svm__C  \
# 13       0.311695               rbf            0.051        35.01
# 10      12.943975            linear            0.751        90.01
# 0        5.742492            linear            0.601        60.01
# 4        6.254534            linear            0.951        85.01
# 18      13.549172            linear            0.551        75.01
#
#    param_select__k                                             params  \
# 13              15  {'svm__kernel': 'rbf', 'svm__gamma': 0.0510000...
# 10              95  {'svm__kernel': 'linear', 'svm__gamma': 0.751,...
# 0              103  {'svm__kernel': 'linear', 'svm__gamma': 0.6010...
# 4              101  {'svm__kernel': 'linear', 'svm__gamma': 0.9510...
# 18              51  {'svm__kernel': 'linear', 'svm__gamma': 0.551,...
#
#     mean_test_score  std_test_score  rank_test_score
# 13         0.485307        0.063828                1
# 10         0.465789        0.067647                2
# 0          0.457657        0.062196                3
# 4          0.439807        0.045201                4
# 18         0.435709        0.098560                5
# Results for split 5:
#     mean_fit_time param_svm__kernel param_svm__gamma param_svm__C  \
# 13       0.326469               rbf            0.051        35.01
# 18      14.787167            linear            0.551        75.01
# 14       2.302530            linear            0.801        20.01
# 8        0.775197            linear            0.401        20.01
# 10      10.473301            linear            0.751        90.01
#
#    param_select__k                                             params  \
# 13              15  {'svm__kernel': 'rbf', 'svm__gamma': 0.0510000...
# 18              51  {'svm__kernel': 'linear', 'svm__gamma': 0.551,...
# 14              36  {'svm__kernel': 'linear', 'svm__gamma': 0.801,...
# 8              142  {'svm__kernel': 'linear', 'svm__gamma': 0.401,...
# 10              95  {'svm__kernel': 'linear', 'svm__gamma': 0.751,...
#
#     mean_test_score  std_test_score  rank_test_score
# 13         0.487429        0.089706                1
# 18         0.454439        0.086835                2
# 14         0.424188        0.049030                3
# 8          0.419535        0.080942                4
# 10         0.412090        0.065468                5

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### Training-Testing using k-best feature selection

# %%
rs = StratifiedShuffleSplit(n_splits=N_SPLITS, test_size=.3, random_state=RANDOM_SEED)

scores_rf = {'f1': [], 'accuracy': [], 'AUC': []}
fitted_clf_list_rf = []

fig, axs = plt.subplots(N_SPLITS, figsize=(10, 10))

for i, (train_index, test_index) in enumerate(rs.split(X, y)):

    # Data split
    X_train = X.iloc[train_index]
    y_train = y[train_index]
    X_test = X.iloc[test_index]
    y_test = y[test_index]

    # Preprocessing
    scaler = StandardScaler()
    selector = SelectKBest()
    
    # Classifier
    random_forest = RandomForestClassifier(random_state=RANDOM_SEED)

    # Pipeline
    pipe = Pipeline(steps=[('select', selector), ("random_forest", random_forest)])

    # GridSearch

    # Random grid:
    pca_components = [None] + list(np.arange(1, 101, 20))
    n_estimators = [int(x) for x in np.linspace(start=50, stop=200)]
    max_features = ['auto', 'sqrt', 'log2', 0.1]
    max_depth = [int(x) for x in np.linspace(10, 120, num = 12)]
    min_samples_leaf = [1, 3, 5]
    bootstrap = [True, False]

    random_grid = {'random_forest__n_estimators': n_estimators,
    'random_forest__max_features': max_features,
    'random_forest__max_depth': max_depth,
    'random_forest__min_samples_leaf': min_samples_leaf,
    'random_forest__bootstrap': bootstrap,
    'select__k': np.arange(2,150)}
 
    search = RandomizedSearchCV(pipe, random_grid, cv=5, scoring = 'f1', n_iter=20, random_state=RANDOM_SEED)
    search.fit(X_train, y_train)
    best_clf = search.best_estimator_
    fitted_clf_list_rf.append(search)


    # Evaluation
    y_pred = best_clf.predict(X_test)
    y_score = best_clf.predict_proba(X_test)
    scores_rf['f1'] += [f1_score(y_test, y_pred)]
    scores_rf['accuracy'] += [accuracy_score(y_test, y_pred)]
    scores_rf['AUC'] += [roc_auc_score(y_test, y_score[:,1])]

    # Predictions
    scores_rf[f'probs_split_{i+1}'] = y_score
    scores_rf[f'labels_split_{i+1}'] = list(y_test)
    
    plot_learning_curve(best_clf, X_train, y_train, axs[i])
    fig.suptitle(f'Learning curve for {str(type(best_clf[-1])).split(".")[-1][:-2]}')
plt.show()

# %% [markdown]
# #### Results - Overall metrics

# %%
print('F1-scores:')
print(f"{scores_rf['f1']}, mean: {np.mean(scores_rf['f1'])}, std: {np.std(scores_rf['f1'])}")
print('Accuracy:')
print(f"{scores_rf['accuracy']}, mean: {np.mean(scores_rf['accuracy'])}, std: {np.std(scores_rf['accuracy'])}")
print('AUC:')
print(f"{scores_rf['AUC']}, mean: {np.mean(scores_rf['AUC'])}, std: {np.std(scores_rf['AUC'])}")
# Out:
# F1-scores:
# [0.39436619718309857, 0.3870967741935484, 0.1923076923076923, 0.28571428571428575, 0.3283582089552239], mean: 0.3175686316707698, std: 0.0742340163748418
# Accuracy:
# [0.8273092369477911, 0.8473895582329317, 0.8313253012048193, 0.8393574297188755, 0.8192771084337349], mean: 0.8329317269076306, std: 0.00970525781011613
# AUC:
# [0.8039356984478936, 0.7597560975609756, 0.8003880266075388, 0.7569844789356986, 0.7052106430155212], mean: 0.7652549889135256, std: 0.03587336126824691

# %% [markdown]
# #### Results - Hyperparameter search

# %%
import pandas as pd
for i, clf in enumerate(fitted_clf_list_rf): 
    print(f'Results for split {i+1}:')
    param_df = pd.DataFrame(clf.cv_results_)

    # columns to drop from dataframe:
    param_df = param_df.drop(['std_fit_time', 'mean_score_time', 'std_score_time'], axis=1)
    cols = [c for c in param_df.columns if c.lower()[:5] != 'split']
    
    param_df = param_df[cols].sort_values(by='rank_test_score')
    display(param_df.head(5))
# Out:
# Results for split 1:
#     mean_fit_time param_select__k param_random_forest__n_estimators  \
# 0        1.105998              69                               163
# 13       0.941734             143                               154
# 11       0.833290              69                               166
# 17       0.710602              91                               147
# 15       0.823004              53                               196
#
#    param_random_forest__min_samples_leaf param_random_forest__max_features  \
# 0                                      1                              auto
# 13                                     1                              log2
# 11                                     3                               0.1
# 17                                     5                              log2
# 15                                     3                              auto
#
#    param_random_forest__max_depth param_random_forest__bootstrap  \
# 0                              80                          False
# 13                             90                          False
# 11                             80                          False
# 17                             40                          False
# 15                             20                           True
#
#                                                params  mean_test_score  \
# 0   {'select__k': 69, 'random_forest__n_estimators...         0.499700
# 13  {'select__k': 143, 'random_forest__n_estimator...         0.491602
# 11  {'select__k': 69, 'random_forest__n_estimators...         0.478248
# 17  {'select__k': 91, 'random_forest__n_estimators...         0.465350
# 15  {'select__k': 53, 'random_forest__n_estimators...         0.460629
#
#     std_test_score  rank_test_score
# 0         0.076513                1
# 13        0.072801                2
# 11        0.089556                3
# 17        0.083928                4
# 15        0.091333                5
# Results for split 2:
#     mean_fit_time param_select__k param_random_forest__n_estimators  \
# 2        0.673374              26                               193
# 5        0.443212              28                               129
# 11       0.751721              69                               166
# 6        0.859205             117                               132
# 18       0.790632             107                               157
#
#    param_random_forest__min_samples_leaf param_random_forest__max_features  \
# 2                                      5                              auto
# 5                                      1                               0.1
# 11                                     3                               0.1
# 6                                      5                               0.1
# 18                                     1                              log2
#
#    param_random_forest__max_depth param_random_forest__bootstrap  \
# 2                              90                           True
# 5                              10                          False
# 11                             80                          False
# 6                              20                          False
# 18                             50                          False
#
#                                                params  mean_test_score  \
# 2   {'select__k': 26, 'random_forest__n_estimators...         0.415099
# 5   {'select__k': 28, 'random_forest__n_estimators...         0.393821
# 11  {'select__k': 69, 'random_forest__n_estimators...         0.392861
# 6   {'select__k': 117, 'random_forest__n_estimator...         0.391583
# 18  {'select__k': 107, 'random_forest__n_estimator...         0.389524
#
#     std_test_score  rank_test_score
# 2         0.080214                1
# 5         0.095931                2
# 11        0.036082                3
# 6         0.056448                4
# 18        0.059278                5
# Results for split 3:
#     mean_fit_time param_select__k param_random_forest__n_estimators  \
# 18       0.808344             107                               157
# 4        0.795009              96                               157
# 11       0.770224              69                               166
# 15       0.784716              53                               196
# 0        0.981351              69                               163
#
#    param_random_forest__min_samples_leaf param_random_forest__max_features  \
# 18                                     1                              log2
# 4                                      1                              log2
# 11                                     3                               0.1
# 15                                     3                              auto
# 0                                      1                              auto
#
#    param_random_forest__max_depth param_random_forest__bootstrap  \
# 18                             50                          False
# 4                             110                          False
# 11                             80                          False
# 15                             20                           True
# 0                              80                          False
#
#                                                params  mean_test_score  \
# 18  {'select__k': 107, 'random_forest__n_estimator...         0.492541
# 4   {'select__k': 96, 'random_forest__n_estimators...         0.486294
# 11  {'select__k': 69, 'random_forest__n_estimators...         0.477504
# 15  {'select__k': 53, 'random_forest__n_estimators...         0.475088
# 0   {'select__k': 69, 'random_forest__n_estimators...         0.474132
#
#     std_test_score  rank_test_score
# 18        0.099140                1
# 4         0.067531                2
# 11        0.067974                3
# 15        0.085514                4
# 0         0.037538                5
# Results for split 4:
#     mean_fit_time param_select__k param_random_forest__n_estimators  \
# 13       0.896074             143                               154
# 3        0.405466              24                                74
# 18       0.821024             107                               157
# 5        0.451215              28                               129
# 0        1.010116              69                               163
#
#    param_random_forest__min_samples_leaf param_random_forest__max_features  \
# 13                                     1                              log2
# 3                                      5                              log2
# 18                                     1                              log2
# 5                                      1                               0.1
# 0                                      1                              auto
#
#    param_random_forest__max_depth param_random_forest__bootstrap  \
# 13                             90                          False
# 3                              60                          False
# 18                             50                          False
# 5                              10                          False
# 0                              80                          False
#
#                                                params  mean_test_score  \
# 13  {'select__k': 143, 'random_forest__n_estimator...         0.464970
# 3   {'select__k': 24, 'random_forest__n_estimators...         0.451043
# 18  {'select__k': 107, 'random_forest__n_estimator...         0.450611
# 5   {'select__k': 28, 'random_forest__n_estimators...         0.450038
# 0   {'select__k': 69, 'random_forest__n_estimators...         0.429569
#
#     std_test_score  rank_test_score
# 13        0.039543                1
# 3         0.022096                2
# 18        0.049658                3
# 5         0.043022                4
# 0         0.029203                5
# Results for split 5:
#     mean_fit_time param_select__k param_random_forest__n_estimators  \
# 16       0.564921              18                               147
# 2        0.670142              26                               193
# 6        0.859954             117                               132
# 19       0.669695              58                               157
# 11       0.756456              69                               166
#
#    param_random_forest__min_samples_leaf param_random_forest__max_features  \
# 16                                     5                              auto
# 2                                      5                              auto
# 6                                      5                               0.1
# 19                                     3                              auto
# 11                                     3                               0.1
#
#    param_random_forest__max_depth param_random_forest__bootstrap  \
# 16                             30                          False
# 2                              90                           True
# 6                              20                          False
# 19                            120                           True
# 11                             80                          False
#
#                                                params  mean_test_score  \
# 16  {'select__k': 18, 'random_forest__n_estimators...         0.467098
# 2   {'select__k': 26, 'random_forest__n_estimators...         0.446719
# 6   {'select__k': 117, 'random_forest__n_estimator...         0.434887
# 19  {'select__k': 58, 'random_forest__n_estimators...         0.427005
# 11  {'select__k': 69, 'random_forest__n_estimators...         0.426961
#
#     std_test_score  rank_test_score
# 16        0.134601                1
# 2         0.121207                2
# 6         0.089743                3
# 19        0.117826                4
# 11        0.120760                5

# %% [markdown]
# ## Statistical analysis

# %% [markdown]
# ### Create table of p-values (significant values are green)

# %%
classifiers_used = ['K-NN', 'Naive Bayes', 'SVM', 'Random Forest']

names = combinations(classifiers_used, 2)
comb = combinations([scores_knn['f1'], scores_nb['f1'], scores_svm['f1'], scores_rf['f1']], 2)

# Print the obtained combinations
p_values_table = pd.DataFrame(index=classifiers_used, columns=classifiers_used)

for name, scores in zip(list(names), list(comb)):
    _, p_value = ttest_ind(scores[0], scores[1])
    p_values_table[name[0]][name[1]] = p_value
    p_values_table[name[1]][name[0]] = p_value

# %%
def _color_green(val):
    color = 'grey' if val == '-' else ('green' if float(val) < 0.05 else 'black')
    return 'color: %s' % color

# %%
p_values_table = p_values_table.replace(pd.NA, '-')
p_values_table = p_values_table.style.applymap(_color_green)
display(p_values_table)
# Out:
# <style type="text/css">
# #T_97f12_row0_col0, #T_97f12_row1_col1, #T_97f12_row2_col2, #T_97f12_row3_col3 {
#   color: grey;
# }
# #T_97f12_row0_col1, #T_97f12_row0_col2, #T_97f12_row1_col0, #T_97f12_row2_col0 {
#   color: green;
# }
# #T_97f12_row0_col3, #T_97f12_row1_col2, #T_97f12_row1_col3, #T_97f12_row2_col1, #T_97f12_row2_col3, #T_97f12_row3_col0, #T_97f12_row3_col1, #T_97f12_row3_col2 {
#   color: black;
# }
# </style>
# <table id="T_97f12_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >K-NN</th>
#       <th class="col_heading level0 col1" >Naive Bayes</th>
#       <th class="col_heading level0 col2" >SVM</th>
#       <th class="col_heading level0 col3" >Random Forest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97f12_level0_row0" class="row_heading level0 row0" >K-NN</th>
#       <td id="T_97f12_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_97f12_row0_col1" class="data row0 col1" >0.043611</td>
#       <td id="T_97f12_row0_col2" class="data row0 col2" >0.005356</td>
#       <td id="T_97f12_row0_col3" class="data row0 col3" >0.761019</td>
#     </tr>
#     <tr>
#       <th id="T_97f12_level0_row1" class="row_heading level0 row1" >Naive Bayes</th>
#       <td id="T_97f12_row1_col0" class="data row1 col0" >0.043611</td>
#       <td id="T_97f12_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_97f12_row1_col2" class="data row1 col2" >0.480926</td>
#       <td id="T_97f12_row1_col3" class="data row1 col3" >0.221222</td>
#     </tr>
#     <tr>
#       <th id="T_97f12_level0_row2" class="row_heading level0 row2" >SVM</th>
#       <td id="T_97f12_row2_col0" class="data row2 col0" >0.005356</td>
#       <td id="T_97f12_row2_col1" class="data row2 col1" >0.480926</td>
#       <td id="T_97f12_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_97f12_row2_col3" class="data row2 col3" >0.076953</td>
#     </tr>
#     <tr>
#       <th id="T_97f12_level0_row3" class="row_heading level0 row3" >Random Forest</th>
#       <td id="T_97f12_row3_col0" class="data row3 col0" >0.761019</td>
#       <td id="T_97f12_row3_col1" class="data row3 col1" >0.221222</td>
#       <td id="T_97f12_row3_col2" class="data row3 col2" >0.076953</td>
#       <td id="T_97f12_row3_col3" class="data row3 col3" >-</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Boxplot for F1-scores of the different ML algorithms used

# %%
scores_df = pd.DataFrame({'K-NN': scores_knn['f1'], 'Naive Bayes': scores_nb['f1'], 'SVM': scores_svm['f1'], 'Random Forest': scores_rf['f1']})

ax = seaborn.boxplot(data=scores_df)
ax.set_ylabel('F1-score')
ax.set_title('Boxplot F1-scores on test sets')
# Out:
# Text(0.5, 1.0, 'Boxplot F1-scores on test sets')

# %% [markdown]
# ### ROC and Precision-Recall curve

# %%
# Code adapted from:
# https://stackoverflow.com/questions/51442818/average-roc-curve-across-folds-for-multi-class-classification-case-in-sklearn
# %matplotlib inline
plt.rcParams.update({'font.size': 14})

scores_dict = [scores_knn, scores_nb, scores_svm, scores_rf]
classifiers_used = ['K-NN', 'Naive Bayes', 'SVM', 'Random Forest']

colors = ['darksalmon', 'gold', 'royalblue', 'mediumseagreen', 'violet']

fig, axs = plt.subplots(1, 2, figsize=(24, 12))

for dict, name in zip(scores_dict, classifiers_used):
    tprs = []
    aucs = []
    base_fpr = np.linspace(0, 1, 101)

    for i in range(N_SPLITS):
        fpr, tpr, _ = roc_curve(dict[f'labels_split_{i+1}'], dict[f'probs_split_{i+1}'][:, 1])
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        tpr = np.interp(base_fpr, fpr, tpr)
        tpr[0] = 0.0
        tprs.append(tpr)

    tprs = np.array(tprs)
    mean_tprs = tprs.mean(axis=0)
    std = tprs.std(axis=0)

    mean_auc = auc(base_fpr, mean_tprs)
    std_auc = np.std(aucs)

    tprs_upper = np.minimum(mean_tprs + std, 1)
    tprs_lower = mean_tprs - std

    axs[0].plot(base_fpr, mean_tprs, alpha = 0.8, label=r'%s mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (name, mean_auc, std_auc),)
    axs[0].fill_between(base_fpr, tprs_lower, tprs_upper, alpha = 0.2)

axs[0].plot([0, 1], [0, 1], linestyle = '--', lw = 2, color = 'r', label = 'TPR=FPR', alpha= 0.8)
axs[0].set_xlim([-0.01, 1.01])
axs[0].set_ylim([-0.01, 1.01])
axs[0].set_ylabel('True Positive Rate')
axs[0].set_xlabel('False Positive Rate')
axs[0].legend(loc="lower right")
axs[0].set_title('Receiver operating characteristic (ROC) curves')

f_scores = np.linspace(0.2, 0.8, num=4)
lines, labels = [], []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    (l,) = plt.plot(x[y >= 0], y[y >= 0], color="gray", alpha=0.2)
    plt.annotate("f1={0:0.1f}".format(f_score), xy=(0.9, y[45] + 0.02))

for dict, name in zip(scores_dict, classifiers_used):
    precision = []
    pr_auc = []
    base_recall = np.linspace(0, 1, 101)

    for i in range(N_SPLITS):
        prec, rec, _ = precision_recall_curve(dict[f'labels_split_{i+1}'], dict[f'probs_split_{i+1}'][:, 1])
        prec = np.flip(prec)
        rec = np.flip(rec)
        auc_temp = auc(rec, prec)
        pr_auc.append(auc_temp)
        prec = np.interp(base_recall, rec, prec)
        precision.append(prec)

    precision = np.array(precision)
    mean_precisions = np.mean(precision, axis=0)
    std = precision.std(axis=0)

    mean_auc = np.mean(pr_auc)
    std_auc = np.std(pr_auc)

    axs[1].plot(base_recall, mean_precisions, alpha = 0.8, label=r'%s mean PR (AUC = %0.2f $\pm$ %0.2f)' % (name, mean_auc, std_auc),)
    

    prec_upper = np.minimum(mean_precisions + std, 1)
    prec_lower = mean_precisions - std
    axs[1].fill_between(base_recall, prec_lower, prec_upper, alpha = 0.2)

axs[1].plot([0, 1], [0.5, 0.5], linestyle = '--', lw = 2, color = 'r', label = 'Baseline', alpha= 0.8)
axs[1].set_xlim([-0.01, 1.01])
axs[1].set_ylim([-0.01, 1.01])
axs[1].set_ylabel('Precision')
axs[1].set_xlabel('Recall')
axs[1].legend(loc="upper right")
axs[1].set_title('Precision-recall curves')
plt.subplots_adjust(wspace=0.1, hspace=0)
#plt.tight_layout()

# %% [markdown]
# ## Intermediate steps

# %% [markdown]
# #### k-NN Training-Testing using Standard Scaler and PCA (hidden)
# Performance for this pipeline was less compared to using the k-best feature selection (above).

# %%
rs = StratifiedShuffleSplit(n_splits=N_SPLITS, test_size=.3, random_state=RANDOM_SEED)

scores_knn = {'f1': [], 'accuracy': [], 'AUC': []}
fitted_clf_list_knn = []

fig, axs = plt.subplots(N_SPLITS, figsize=(10, 10))

for i, (train_index, test_index) in enumerate(rs.split(X, y)):

    # Data split
    X_train = X.iloc[train_index]
    y_train = y[train_index]
    X_test = X.iloc[test_index]
    y_test = y[test_index]

    # Preprocessing
    scaler = StandardScaler()
    knn = KNeighborsClassifier()
    pca = PCA()
    selector = SelectKBest()

    # Pipeline
    pipe = Pipeline(steps=[('scaler', scaler), ('pca', pca), ("knn", knn)])

    # GridSearch

    # Random grid:
    pca_components = [None] + list(np.arange(1, 101, 20))
    k_range = list(range(1, 31))
    weights = ['uniform', 'distance']
    k_select = np.arange(2, 150)

    random_grid = {'knn__n_neighbors': k_range,
    'knn__weights': weights,
    'pca__n_components': pca_components}
    #'select__k': k_select}

    # Hoeveel iteraties willen we?
    search = RandomizedSearchCV(pipe, random_grid, cv=5, scoring = 'f1', n_iter=20, random_state=RANDOM_SEED)
    search.fit(X_train, y_train)
    best_clf = search.best_estimator_
    fitted_clf_list_knn.append(search)
    
    # evaluation
    y_pred = best_clf.predict(X_test)
    scores_knn['f1'] += [f1_score(y_test, y_pred)]
    scores_knn['accuracy'] += [accuracy_score(y_test, y_pred)]
    scores_knn['AUC'] += [roc_auc_score(y_test, y_pred)]
    
    plot_learning_curve(best_clf, X_train, y_train, axs[i]) # eventueel testen met groot aantal neighbors
    fig.suptitle(f'Learning curve for {str(type(best_clf[-1])).split(".")[-1][:-2]}')
plt.show()

# %% [markdown]
# #### Naive Bayes Training-Testing using Standard Scaler and PCA (hidden)
# Performance for this pipeline was less compared to using the k-best feature selection (above).

# %%
rs = StratifiedShuffleSplit(n_splits=N_SPLITS, test_size=.3, random_state=RANDOM_SEED)

scores_nb = {'f1': [], 'accuracy': [], 'AUC': []}
fitted_clf_list_nb = []

fig, axs = plt.subplots(N_SPLITS, figsize=(10, 10))

for i, (train_index, test_index) in enumerate(rs.split(X, y)):

    # Data split
    X_train = X.iloc[train_index]
    y_train = y[train_index]
    X_test = X.iloc[test_index]
    y_test = y[test_index]

    # Preprocessing
    scaler = StandardScaler()
    naive_bayes = GaussianNB()
    pca = PCA()

    # Pipeline
    pipe = Pipeline(steps=[('scaler', scaler), ('pca', pca), ("nbayes", naive_bayes)])

    # Random grid:
    pca_components = [None] + list(np.arange(1, 101, 20))
    var_smoothing = np.logspace(0,-9, num=100)
    k_select = np.arange(2, 150)

    random_grid = {'nbayes__var_smoothing': var_smoothing,
    #'pca__n_components': pca_components}
    'select__k': k_select}

    search = RandomizedSearchCV(pipe, random_grid, cv=5, scoring = 'f1', n_iter= 20, random_state=RANDOM_SEED)
    search.fit(X_train, y_train)
    best_clf = search.best_estimator_
    fitted_clf_list_nb.append(search)

    # Evaluation
    y_pred = best_clf.predict(X_test)
    scores_nb['f1'] += [f1_score(y_test, y_pred)]
    scores_nb['accuracy'] += [accuracy_score(y_test, y_pred)]
    scores_nb['AUC'] += [roc_auc_score(y_test, y_pred)]
    
    plot_learning_curve(best_clf, X_train, y_train, axs[i])
    fig.suptitle(f'Learning curve for {str(type(best_clf[-1])).split(".")[-1][:-2]}')
plt.show()

# %% [markdown]
# #### Random forest Training-Testing using Standard Scaler and PCA (hidden)
# Performance for this pipeline was less compared to using the k-best feature selection (above).

# %%
rs = StratifiedShuffleSplit(n_splits=N_SPLITS, test_size=.3, random_state=RANDOM_SEED)

scores_rf = {'f1': [], 'accuracy': [], 'AUC': []}
fitted_clf_list_rf = []

fig, axs = plt.subplots(N_SPLITS, figsize=(10, 10))

for i, (train_index, test_index) in enumerate(rs.split(X, y)):

    # Data split
    X_train = X.iloc[train_index]
    y_train = y[train_index]
    X_test = X.iloc[test_index]
    y_test = y[test_index]

    # Preprocessing
    scaler = StandardScaler()
    random_forest = RandomForestClassifier()
    pca = PCA()

    # Pipeline
    pipe = Pipeline(steps=[('scaler', scaler), ('pca', pca), ("random_forest", random_forest)])

    # GridSearch

    # Random grid:
    pca_components = [None] + list(np.arange(1, 101, 20))
    n_estimators = [int(x) for x in np.linspace(start=50, stop=200)]
    max_features = ['auto', 'sqrt', 'log2', 0.1]
    max_depth = [int(x) for x in np.linspace(10, 120, num = 12)]
    min_samples_leaf = [1, 3, 5]
    bootstrap = [True, False]

    random_grid = {'random_forest__n_estimators': n_estimators,
    'random_forest__max_features': max_features,
    'random_forest__max_depth': max_depth,
    'random_forest__min_samples_leaf': min_samples_leaf,
    'random_forest__bootstrap': bootstrap,
    'pca__n_components': pca_components}
 
    search = RandomizedSearchCV(pipe, random_grid, cv=5, scoring = 'f1', verbose=2, n_iter=20, random_state=RANDOM_SEED)
    search.fit(X_train, y_train)
    best_clf = search.best_estimator_
    fitted_clf_list_rf.append(search)


    # Evaluation
    y_pred = best_clf.predict(X_test)
    y_score = best_clf.predict_proba(X_test)
    scores_rf['f1'] += [f1_score(y_test, y_pred)]
    scores_rf['accuracy'] += [accuracy_score(y_test, y_pred)]
    scores_rf['AUC'] += [roc_auc_score(y_test, y_score[:,1])]

    # Predictions
    scores_rf[f'probs_split_{i+1}'] = y_score
    scores_rf[f'labels_split_{i+1}'] = list(y_test)
    
    plot_learning_curve(best_clf, X_train, y_train, axs[i])
    fig.suptitle(f'Learning curve for {str(type(best_clf[-1])).split(".")[-1][:-2]}')
plt.show()

# %% [markdown]
# #### SVM Training-Testing using Standard Scaler and PCA (hidden)
# Performance for this pipeline was less compared to using the k-best feature selection (above).

# %%
# Aantal splits
N_SPLITS = 5

rs = StratifiedShuffleSplit(n_splits=N_SPLITS, test_size=.3, random_state=RANDOM_SEED)

scores_svm = {'f1': [], 'accuracy': [], 'AUC': []}
fitted_clf_list_svm = []

fig, axs = plt.subplots(N_SPLITS, figsize=(10, 10))

for i, (train_index, test_index) in enumerate(rs.split(X, y)):

    # Data split
    X_train = X.iloc[train_index]
    y_train = y[train_index]
    X_test = X.iloc[test_index]
    y_test = y[test_index]

    # Preprocessing
    scaler = StandardScaler()
    pca = PCA()

    # classifier 
    classifier = svm.SVC(probability=True)
  
    # Pipeline
    pipe = Pipeline(steps=[('scaler', scaler), ('pca', pca), ('svm', classifier)])

    # GridSearch

    # Random grid:
    random_grid = {
        #'pca__n_components': [None, 10,50,100],
            'svm__C': list(np.arange(0.01,100, 5)),
            'svm__gamma': list(np.arange(0.001, 1, 0.05)), 
            'svm__kernel': ['rbf', 'poly', 'linear'],
            'pca__n_components': [None] + list(np.arange(1, 101, 20))} 

    search = RandomizedSearchCV(pipe, random_grid, cv=5, scoring = 'f1', n_iter= 20, random_state=RANDOM_SEED)
    search.fit(X_train, y_train)
    best_clf = search.best_estimator_
    fitted_clf_list_svm.append(search)

    # evaluation
    y_pred = best_clf.predict(X_test)
    y_score = best_clf.predict_proba(X_test)
    scores_svm['f1'] += [f1_score(y_test, y_pred)]
    scores_svm['accuracy'] += [accuracy_score(y_test, y_pred)]
    scores_svm['AUC'] += [roc_auc_score(y_test, y_score[:,1])]

    # Predictions
    scores_svm[f'probs_split_{i+1}'] = y_score
    scores_svm[f'labels_split_{i+1}'] = list(y_test)
    
    plot_learning_curve(best_clf, X_train, y_train, axs[i])
    fig.suptitle(f'Learning curve for {str(type(best_clf[-1])).split(".")[-1][:-2]}')
plt.show()
